# %%
with open("pg37431.txt") as f:
    print(f.read(60))
# Out:
# _PRIDE AND PREJUDICE_
#
# _A PLAY_
#
# _FOUNDED ON JANE AUSTEN'S
# N

# %%
with open("pg37431.txt") as f:
    print(f.readline())
# Out:
# _PRIDE AND PREJUDICE_

# %%
"""Writing the content to a file"""
f = open('log.txt','w')
from datetime import datetime
import time
for i in range(0,10):
    print(datetime.now().strftime('%Y%m%d_%H:%M:%S - '),i)
    f.write(datetime.now().strftime('%Y%m%d_%H:%M:%S - '))
    time.sleep(1)
    f.write(str(i))
    f.write("\n")
f.close()
# Out:
# 20200122_17:54:28 -  0
# 20200122_17:54:29 -  1
# 20200122_17:54:30 -  2
# 20200122_17:54:31 -  3
# 20200122_17:54:32 -  4
# 20200122_17:54:33 -  5
# 20200122_17:54:34 -  6
# 20200122_17:54:35 -  7
# 20200122_17:54:36 -  8
# 20200122_17:54:37 -  9

# %%
"""Working with assertion """
def avg(marks):
    assert len(marks) != 0, "Invalid marks"
    return round(sum(marks)/len(marks),2)


sem1_marks = [62,65,75]
print("Average marks for semester 1 :",avg(sem1_marks))
ranks = []
print("Average of marks for semester 1:",avg(ranks))
# Out:
# Average marks for semester 1 : 67.33
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-18-f9b5543a7ec0> in <module>
#       8 print("Average marks for semester 1 :",avg(sem1_marks))
#       9 ranks = []
# ---> 10 print("Average of marks for semester 1:",avg(ranks))
#
# <ipython-input-18-f9b5543a7ec0> in avg(marks)
#       1 """Working with assertion """
#       2 def avg(marks):
# ----> 3     assert len(marks) != 0, "Invalid marks"
#       4     return round(sum(marks)/len(marks),2)
#       5
#
# AssertionError: Invalid marks

# %%
# Out:
# Average marks for semester 1 : 67.33
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-17-139cd236e11f> in <module>
#       2 print("Average marks for semester 1 :",avg(sem1_marks))
#       3 ranks = []
# ----> 4 print("Average of marks for semester 1:",avg(ranks))
#
# <ipython-input-16-a815b52ab5b1> in avg(marks)
#       1 """Working with assertion """
#       2 def avg(marks):
# ----> 3     assert len(marks) != 0, "Invalid marks"
#       4     return round(sum(marks)/len(marks),2)
#
# AssertionError: Invalid marks

# %%
"""Using python we will draw a Scatter Plot"""
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

temperature = [14.2, 16.4, 11.9, 12.5, 18.9, 22.1, 19.4, 23.1, 25.4, 18.1, 22.6, 17.2]
sales = [215.20, 325.00, 185.20, 330.20, 418.60, 520.25, 412.20, 614.60, 544.80, 421.40, 445.50, 408.10]

plt.title("Ice-cream sales versus Temperature",loc = 'center')
plt.xlabel("Sales")
plt.ylabel("Temperatures")

plt.scatter(temperature, sales, color = "red")
plt.show()
#help(plt.title)
# Out:
# Help on function title in module matplotlib.pyplot:
#
# title(label, fontdict=None, loc='center', pad=None, **kwargs)
#     Set a title for the axes.
#
#     Set one of the three available axes titles. The available titles
#     are positioned above the axes in the center, flush with the left
#     edge, and flush with the right edge.
#
#     Parameters
#     ----------
#     label : str
#         Text to use for the title
#
#     fontdict : dict
#         A dictionary controlling the appearance of the title text,
#         the default `fontdict` is::
#
#            {'fontsize': rcParams['axes.titlesize'],
#             'fontweight' : rcParams['axes.titleweight'],
#             'verticalalignment': 'baseline',
#             'horizontalalignment': loc}
#
#     loc : {'center', 'left', 'right'}, str, optional
#         Which title to set, defaults to 'center'
#
#     pad : float
#         The offset of the title from the top of the axes, in points.
# ...

# %%
"""Drawing a line chart of the stock price"""
import matplotlib.pyplot as plt

stock_price = [190.64, 190.09, 192.25, 191.79, 194.45, 196.45, 196.45,
196.42, 200.32, 200.32, 200.85, 199.2, 199.2, 199.2, 199.46, 201.46,
197.54, 201.12, 203.12, 203.12, 203.12, 202.83, 202.83, 203.36, 206.83,
204.9, 204.9, 204.9, 204.4, 204.06]

t = list(range(1,31))
        

plt.plot(t,stock_price, marker = ".",color = 'red')
plt.title('Opeaning Stock Prices')
plt.xlabel("Days")
plt.ylabel("$ USD")
plt.xticks([1,8.5,15,22,28])
plt.show()

# %%
"""Drawing the Bar charts to display the data of students and corresponding bar plots"""
grades = ['A', 'B', 'C', 'D', 'E', 'F']
students_count = [20, 30, 10, 5, 8, 2]

import matplotlib.pyplot as plt
plt.title('Grades Bar Plot for Biology Class')
plt.xlabel('Grade')
plt.ylabel("Number of Students")
plt.bar(grades,students_count, color = ['green', 'gray', 'red' , 'blue'])
plt.show()
plt.ylabel('Grade')
plt.xlabel("Number of Students")
plt.barh(grades,students_count, color = ['green', 'gray', 'red' , 'blue'])
plt.show()

# %%
"""Creating a pie chart to visualize the number of votes in a school"""
# %matplotlib inline
#plotting
labels = ['Monica','Adrian','Jared']
num = [230, 100, 98]

import matplotlib.pyplot as plt
#plt.pie(num, labels = labels, autopct = '%1.1f%%', colors = ['lightblue','lightgreen', 'yellow'])
plt.title('Voting Results : Club President', fontdict = {'fontsize':20})
plt.pie(num,labels=labels, autopct =' %1.1f%%',colors = ['lightblue', 'lightgreen','yellow'])
plt.show()

# %%
"""Generating the Heatmap"""
def heatmap(data, row_labels, col_labels, ax = None, cbar_kw = {}, cbarlabel = "", **kwargs):
    if not ax:
        ax = plt.gca()
    im = ax.imshow(data, **kwargs)
    
    cbar = ax.figure.colorbar(im,ax=ax,**cbar_kw)
    cbar.ax.set_ylabel(cbarlabel, rotation = -90, va = 'bottom')
    ax.set_xticks(np.arange(data.shape[1]))
    ax.set_yticks(np.arange(data.shape[0]))
    ax.set_xticklabels(col_labels)
    ax.set_yticklabels(row_labels)
    ax.tick_params(top = True, bottom = False, labeltop = True, labelbottom = False)
    plt.setp(ax.get_xticklabels(),rotation = -30, ha = "right", rotation_mode = "anchor")
    
    for edge,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xticks(np.arange(data.shape[1]+1)-.5,minor = True)
    ax.set_yticks(np.arange(data.shape[0]+1)-.5,minor = True)
    ax.grid(which = "minor", color = "w", linestyle = '-' , linewidth = 3)
    ax.tick_params(which = "minor",bottom = False,left = False)
    return im, cbar

# %%
# %matplotlib inline
import numpy as np
#import matplotlib.plyplot as plt
data = np.array([[30,20,10],[10,40,15],[12,10,20]])
im, cbar = heatmap(data,['Class-1','Class-2','Class-3'],['A','B','C'],cmap = 'YlGn',cbarlabel = 'Number of Students')

# %%
def annotate_heatmap(im, data=None, valfmt="{x:.2f}",
textcolors=["black", "white"],
threshold=None, **textkw):
    import matplotlib
    if not isinstance(data, (list, np.ndarray)):
        data = im.get_array()
    if threshold is not None:
         threshold = im.norm(threshold)
    else:
        threshold = im.norm(data.max())/2.
    kw = dict(horizontalalignment="center",verticalalignment="center")
    kw.update(textkw)
    if isinstance(valfmt, str):
        valfmt = matplotlib.ticker.StrMethodFormatter(valfmt)

im, cbar = heatmap(data, ['Class-1', 'Class-2', 'Class-3'], ['A', 'B','C'], cmap='YlGn', cbarlabel='Number of Students')
texts = annotate_heatmap(im, valfmt="{x}")

# %%
"""import seaborn as sns
data = [90, 80, 50, 42, 89, 78, 34, 70, 67, 73, 74, 80, 60, 90, 90]
sns.distplot(data)
"""
import matplotlib.pyplot as plt
plt.title('Density Plot')
plt.xlabel('Score')
plt.ylabel('Density')
sns.distplot(data)
plt.show()

# %%
weight=[85.08,79.25,85.38,82.64,80.51,77.48,79.25,78.75,77.21,73.11,82.03,
        82.54,74.62,79.82,79.78,77.94,83.43,73.71,80.23,78.27,78.25,80.00,76.21,86.65,
        78.22,78.51,79.60,83.88,77.68,78.92,79.06,85.30,82.41,79.70,80.16,81.11,
        79.58,77.42,75.82,74.09,78.31,83.17,75.20,76.14]
import seaborn as sns
#sns.kdeplot(list(range(1,45)),weight,kind = 'kde',cmap = "Reds",)
import matplotlib.pyplot as plt
plt.legend(labels = ['a','b'])
plt.title('Weight Dataset-Contour Plot')
plt.ylabel('height(cm)')
plt.xlabel('width(cm)')
sns.kdeplot(list(range(1,45)),weight,kind = 'kde',cmap = "Reds")

# %%
"""Drawing the weight Dataset in a scater plot  and comperting it to te ContourPlot"""
weight=[85.08,79.25,85.38,82.64,80.51,77.48,79.25,78.75,77.21,73.11,82.03,
        82.54,74.62,79.82,79.78,77.94,83.43,73.71,80.23,78.27,78.25,80.00,76.21,86.65,
        78.22,78.51,79.60,83.88,77.68,78.92,79.06,85.30,82.41,79.70,80.16,81.11,
        79.58,77.42,75.82,74.09,78.31,83.17,75.20,76.14]

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np



plt.title("Ice-cream sales versus Temperature",loc = 'center')
plt.xlabel("Sales")
plt.ylabel("Temperatures")

plt.scatter(list(range(1,45)),weight, color = "red")
plt.show()
#help(plt.title)

# %%
"""Extending the Graphs using the Subplots"""
import matplotlib.pyplot as plt
#spliting the figure into 2 subplots
fig = plt.figure(figsize = (8,4))
ax1 = fig.add_subplot(121)  #IMP!! here 121 means split into 1 row, 2columns, and put in 1st part.
ax2 = fig.add_subplot(122)  #Imp!! here 122 means split into 1 row, 2 columns andput in 2nd part.
#Ploting the 1st chart
labels = ['Adrain', "Monica","Jared"]
num = [230,100, 98]
ax1.pie(num,labels = labels, autopct = '%1.1f%%', colors = ['lightblue','lightgreen','yellow'])
ax1.set_title('Pie Chart (Subplot 1)')

#Plotting the 2nd Chart
labels = ['Adrain',"Monica","Jared"]
num = [230, 100, 98]
plt.bar(labels,num,color = ['lightblue','lightgreen','yellow'])
ax2.set_title("Bar Chart (Subplot 2)")
ax2.set_xlabel('Candidate')
ax2.set_ylabel("Votes")
fig.suptitle("Voting Results",size = 14)
# Out:
# Text(0.5, 0.98, 'Voting Results')

# %%
"""Generating the 3D Plot to Plot a Sine Wave"""
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

X = np.linspace(0,10,50)
Y = np.linspace(0,10,50)
X,Y = np.meshgrid(X,Y)
Z= (np.sin(X))

#Setup axis
fig = plt.figure(figsize = (7,5))
ax = fig.add_subplot(111,projection = '3d')
#using the plot_surface funtion to plot the 3D surface chart
ax.plot_surface(X,Y,Z)
#configuring the titles and axes labels
ax.set_title("Demo of 3D plot",size = 13)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
# Out:
# Text(0.5, 0, 'Z')
